# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img1 = cv2.imread('tt.jpg')
img1 = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
img2 = cv2.imread('dd.png')
img2 = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
img2 = cv2.resize(img2,(600,600))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (667, 1000, 3)

# %%
img2.shape
# Out:
# (600, 600, 3)

# %%
img1 = cv2.resize(img1,(1200,1200))
img2 = cv2.resize(img2,(1200,1200))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.8,src2=img2,gamma=10,beta=0.1)

# %%
plt.imshow(blended)

# %%
u = cv2.imread('man.jpg')
u = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
v = cv2.imread('dd.png')
v = cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)

# %%
u = cv2.resize(u,(1200,1200))

# %%
plt.imshow(u)

# %%
large_img = u
small_img = v

# %%
x_offset = 0
y_offset = 0

# %%
x_end = x_offset + small_img.shape[1]
y_end = y_offset + small_img.shape[0]

# %%
u.shape
# Out:
# (1200, 1200, 3)

# %%
v.shape
# Out:
# (1200, 1200, 3)

# %%
v[y_offset:y_end,x_offset:x_end] = u

# %%
plt.imshow(v)
