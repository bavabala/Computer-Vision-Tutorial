# %%
import numpy as np
import matplotlib.pyplot as plt
import polyline
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('tina.tiff')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img
# Out:
# array([[[ 47,   0,  51],
#         [136, 135, 136],
#         [144, 140, 139],
#         ...,
#         [ 52,  82,  78],
#         [ 63,  74,  72],
#         [ 57,  57,  54]],
#
#        [[ 48,   0,  54],
#         [137, 135, 136],
#         [143, 141, 139],
#         ...,
#         [ 51,  79,  78],
#         [ 64,  74,  72],
#         [ 59,  59,  57]],
#
#        [[ 49,   0,  52],
#         [137, 136, 136],
#         [143, 138, 139],
#         ...,
#         [ 50,  78,  76],
#         [ 62,  71,  74],
#         [ 59,  58,  57]],
#
#        ...,
#
#        [[ 84,   0,  88],
#         [171, 163, 159],
#         [170, 164, 159],
#         ...,
#         [ 61,  83,  84],
#         [ 68,  80,  81],
#         [ 80,  87,  85]],
#
#        [[ 83,   0,  89],
#         [169, 162, 158],
#         [170, 163, 158],
#         ...,
#         [ 59,  82,  83],
#         [ 65,  79,  80],
#         [ 78,  83,  83]],
#
#        [[  0, 200, 111],
#         [217,   0, 127],
#         [218,   0, 127],
# ...

# %%
# MATPLOTLIB ---> RGB RED GREEN BLUE
#OPENCV --->  BLUE GREEN RED

# %%
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('tina.tiff',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (512, 512)

# %%
img_gray.min()
# Out:
# 9

# %%
img_gray.max()
# Out:
# 242

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (512, 512, 3)

# %%
new_img = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new_img)

# %%
w_ratio = 0.8
h_ratio = 0.2

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (102, 410, 3)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (256, 256, 3)

# %%
new_img = cv2.flip(fix_img,0)
plt.imshow(new_img)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(fix_img,text='Hello',org=(10,100),fontFace=font,fontScale=4,color=(255,255,255),thickness=3,lineType=cv2.LINE_AA)
# Out:
# array([[[ 51,   0,  47],
#         [136, 135, 136],
#         [139, 140, 144],
#         ...,
#         [ 78,  82,  52],
#         [ 72,  74,  63],
#         [ 54,  57,  57]],
#
#        [[ 54,   0,  48],
#         [136, 135, 137],
#         [139, 141, 143],
#         ...,
#         [ 78,  79,  51],
#         [ 72,  74,  64],
#         [ 57,  59,  59]],
#
#        [[ 52,   0,  49],
#         [136, 136, 137],
#         [139, 138, 143],
#         ...,
#         [ 76,  78,  50],
#         [ 74,  71,  62],
#         [ 57,  58,  59]],
#
#        ...,
#
#        [[ 88,   0,  84],
#         [159, 163, 171],
#         [159, 164, 170],
#         ...,
#         [ 84,  83,  61],
#         [ 81,  80,  68],
#         [ 85,  87,  80]],
#
#        [[ 89,   0,  83],
#         [158, 162, 169],
#         [158, 163, 170],
#         ...,
#         [ 83,  82,  59],
#         [ 80,  79,  65],
#         [ 83,  83,  78]],
#
#        [[111, 200,   0],
#         [127,   0, 217],
#         [127,   0, 218],
# ...

# %%
plt.imshow(fix_img)

# %%
blank_img = np.zeros(shape=(512,512,3),dtype=np.int32)

# %%
plt.imshow(blank_img)

# %%
vertices = np.array([[200,300],[200,200],[400,300],[200,400]],dtype=np.int32)

# %%
vertices.shape
# Out:
# (4, 2)

# %%
pts = vertices.reshape((-1,1,2))

# %%
pts.shape
# Out:
# (4, 1, 2)

# %%
vertices
# Out:
# array([[200, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]])

# %%
cv2.polylines(blank_img,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(blank_img)
