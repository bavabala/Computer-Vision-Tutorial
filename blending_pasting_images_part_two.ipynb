# %%
import cv2
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy import optimize

# %%
u = cv2.imread('fruity.tiff')
u = cv2.cvtColor(u,cv2.COLOR_BGR2RGB)
v = cv2.imread('lena.tiff')
v = cv2.cvtColor(v,cv2.COLOR_BGR2RGB)
#v = cv2.imwrite('white.jpg')

# %%
#v = cv2.resize(v,(600,600))

# %%
u.shape
# Out:
# (512, 512, 3)

# %%
x_offset = 512
y_offset = 512

# %%
x_offset = 512 - 600
y_offset = 512 - 600
#np.minimum.reduce([u])

# %%
#np.minimum.reduce([v])

# %%
rows,cols,channels = v.shape

# %%
rows
# Out:
# 256

# %%
cols
# Out:
# 256

# %%
final = u[y_offset:512,x_offset:512]

# %%
plt.imshow(final)
